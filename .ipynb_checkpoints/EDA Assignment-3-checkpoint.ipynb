# %%
import pandas as pd

# %%
path=r"C:\Users\pavan kalyan\Desktop\Naresh I technologies\data files\bank.csv"

# %%
bank_df=pd.read_csv(path)

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %%
bank_df
# Out:
#      age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0     30;"unemployed";"married";"primary";"no";1787;...
# 1     33;"services";"married";"secondary";"no";4789;...
# 2     35;"management";"single";"tertiary";"no";1350;...
# 3     30;"management";"married";"tertiary";"no";1476...
# 4     59;"blue-collar";"married";"secondary";"no";0;...
# ...                                                 ...
# 4516  33;"services";"married";"secondary";"no";-333;...
# 4517  57;"self-employed";"married";"tertiary";"yes";...
# 4518  57;"technician";"married";"secondary";"no";295...
# 4519  28;"blue-collar";"married";"secondary";"no";11...
# 4520  44;"entrepreneur";"single";"tertiary";"no";113...
#
# [4521 rows x 1 columns]

# %%
bank_df
# Out:
#      age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0     30;"unemployed";"married";"primary";"no";1787;...
# 1     33;"services";"married";"secondary";"no";4789;...
# 2     35;"management";"single";"tertiary";"no";1350;...
# 3     30;"management";"married";"tertiary";"no";1476...
# 4     59;"blue-collar";"married";"secondary";"no";0;...
# ...                                                 ...
# 4516  33;"services";"married";"secondary";"no";-333;...
# 4517  57;"self-employed";"married";"tertiary";"yes";...
# 4518  57;"technician";"married";"secondary";"no";295...
# 4519  28;"blue-collar";"married";"secondary";"no";11...
# 4520  44;"entrepreneur";"single";"tertiary";"no";113...
#
# [4521 rows x 1 columns]

# %%
bank_df=pd.read_csv(path,sep=';')
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
a=10
b="20"
c=a+int(b)
print(c)
# Out:
# 30

# %%
#bank_df=pd.read_csv("bank.csv")
bank_df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
cat_columns=bank_df.select_dtypes(include='object').columns
num_columns=bank_df.select_dtypes(exclude='object').columns
cat_columns
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')

# %%
bank_df.marital
# Out:
# 0       married
# 1       married
# 2        single
# 3       married
# 4       married
#          ...
# 4516    married
# 4517    married
# 4518    married
# 4519    married
# 4520     single
# Name: marital, Length: 4521, dtype: object

# %%
bank_df[['marital']]
# Out:
#       marital
# 0     married
# 1     married
# 2      single
# 3     married
# 4     married
# ...       ...
# 4516  married
# 4517  married
# 4518  married
# 4519  married
# 4520   single
#
# [4521 rows x 1 columns]

# %%
cdf=bank_df['marital'].value_counts()
keys=cdf.keys()
values=cdf.values# object is not callable  remove brackets
cols=['Labels','Count']
df1=pd.DataFrame(zip(keys,values),
            columns=cols)
df1.to_csv('marital.csv',index=False)

# %%
pd.read_csv('marital.csv')
# Out:
#      Labels  Count
# 0   married   2797
# 1    single   1196
# 2  divorced    528

# %%
marital_df=pd.read_csv('marital.csv')
marital_df
# Out:
#      Labels  Count
# 0   married   2797
# 1    single   1196
# 2  divorced    528

# %%
marital=bank_df['marital'].unique()
count=[]
for i in bank_df['marital'].unique():
        mar=bank_df['marital']==i
        count.append(len(bank_df[mar]))
cols=['marital','Number of Applicants']
pd.DataFrame(zip(marital,count),
            columns=cols)
# Out:
#     marital  Number of Applicants
# 0   married                  2797
# 1    single                  1196
# 2  divorced                   528

# %%
marital=bank_df['marital'].unique()
count=[]
for i in bank_df['marital'].unique():
    mar=bank_df['marital']==i
    count.append(len(bank_df[mar]))
cols=['marital','Number of Applicants']
marital_df=pd.DataFrame(zip(marital,count),
                       columns=cols)
marital_df.to_csv('marital_df.csv',index=False)
marital
# Out:
# array(['married', 'single', 'divorced'], dtype=object)

# %%
marital_df['marital'].value_counts().sum()
# Out:
# 3

# %%
marital_df['marital'].value_counts()
# Out:
# marital
# married     1
# single      1
# divorced    1
# Name: count, dtype: int64

# %%
for i in cat_columns[1:]:
    cdf=bank_df[i].value_counts()
    keys=cdf.keys()
    values=cdf.values
    cols=['Labels','Count']
    df=pd.DataFrame(zip(keys,values),
                   columns=cols)
    path=r"C:\Users\pavan kalyan\Desktop\Naresh I technologies\Data Science\New folder\bank_count"
    marital_df.to_csv(f"{path}\\{i}.csv",index=False)

# %%
import matplotlib.pyplot as plt

# %%
plt.bar('marital',
         'Number of Applicants'
         ,data=marital_df)
plt.title("Marital.Bar Graph")
plt.xlabel("marital")
plt.ylabel("Number of Applicants")
plt.show()

# %%
cdf=bank_df['education'].value_counts()
keys=cdf.keys()
values=cdf.values# object is not callable  remove brackets
cols=['Labels','Count']
df2=pd.DataFrame(zip(keys,values),
            columns=cols)
df2.to_csv('education.csv',index=False)

# %%
pd.read_csv('education.csv')
# Out:
#       Labels  Count
# 0  secondary   2306
# 1   tertiary   1350
# 2    primary    678
# 3    unknown    187

# %%
education=bank_df['education'].unique()
count=[]
for i in bank_df['education'].unique():
        edu=bank_df['education']==i
        count.append(len(bank_df[edu]))
cols=['education','count']
pd.DataFrame(zip(education,count),
            columns=cols)
# Out:
#    education  count
# 0    primary    678
# 1  secondary   2306
# 2   tertiary   1350
# 3    unknown    187

# %%
education_df=pd.DataFrame(zip(education,count),columns=cols)
education_df.to_csv('education_df.csv',index=False)
education_df
# Out:
#    education  count
# 0    primary    678
# 1  secondary   2306
# 2   tertiary   1350
# 3    unknown    187

# %%
for i in cat_columns[1:]:
    cdf=bank_df[i].value_counts()
    keys=cdf.keys()
    
    values=cdf.values
    cols=['education','Number of Applicants']
    education_df=pd.DataFrame(zip(keys,values),
                   columns=cols)
    path=r"C:\Users\pavan kalyan\Desktop\Naresh I technologies\Data Science\New folder\bank_count"
    education_df.to_csv(f"{path}\\{i}.csv",index=False)

# %%
import matplotlib.pyplot as plt

# %%
plt.bar('education',
         'Number of Applicants'
         ,data=education_df)
plt.title("education Bar Graph")
plt.xlabel('education')
plt.ylabel('Number of Applicants')
plt.show()

# %%
bank_df.contact
# Out:
# 0       cellular
# 1       cellular
# 2       cellular
# 3        unknown
# 4        unknown
#           ...
# 4516    cellular
# 4517     unknown
# 4518    cellular
# 4519    cellular
# 4520    cellular
# Name: contact, Length: 4521, dtype: object

# %%
cdf=bank_df['contact'].value_counts()
keys=cdf.keys()
values=cdf.values# object is not callable  remove brackets
cols=['Labels','Count']
df2=pd.DataFrame(zip(keys,values),
            columns=cols)
df2.to_csv('contact.csv',index=False)

# %%
pd.read_csv('contact.csv')
# Out:
#       Labels  Count
# 0   cellular   2896
# 1    unknown   1324
# 2  telephone    301

# %%
contact=bank_df['contact'].unique()
count=[]
for i in bank_df['contact'].unique():
        edu=bank_df['contact']==i
        count.append(len(bank_df[edu]))
cols=['contact','count']
pd.DataFrame(zip(contact,count),
            columns=cols)
# Out:
#      contact  count
# 0   cellular   2896
# 1    unknown   1324
# 2  telephone    301

# %%
contact_df=pd.DataFrame(zip(contact,count),columns=cols)
contact_df.to_csv('contact_df.csv',index=False)
contact_df
# Out:
#      contact  count
# 0   cellular   2896
# 1    unknown   1324
# 2  telephone    301

# %%
import matplotlib.pyplot as plt

# %%
for i in cat_columns[1:]:
    cdf=bank_df[i].value_counts()
    keys=cdf.keys()
    values=cdf.values
    cols=['Labels','count']
    df=pd.DataFrame(zip(keys,values),
                   columns=cols)

# %%
for i in cat_columns[1:]:
    cdf=bank_df[i].value_counts()
    keys=cdf.keys()
    values=cdf.values
    cols=['Labels','count']
    df=pd.DataFrame(zip(keys,values),
                   columns=cols)
    path=r"C:\Users\pavan kalyan\Desktop\Naresh I technologies\Data Science\New folder\bank_count"
    bank_df.to_csv(f"{path}\\{i}.csv",index=False)

# %%
# plt.bar('contact',
#          'count'
#          ,data=contact_df)
# plt.title("contact Bar Graph")
# plt.xlabel('contact')
# plt.ylabel('Number of Applicants')
# plt.show()

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\pavan kalyan\\Desktop\\Naresh I technologies\\Data Science\\New folder'

# %%
root_dir=os.getcwd()
root_dir
# Out:
# 'C:\\Users\\pavan kalyan\\Desktop\\Naresh I technologies\\Data Science\\New folder'

# %%
new_folder='bank_graphs_matplotlib'
new_folder
# Out:
# 'bank_graphs_matplotlib'

# %%
new_dir1=os.path.join(root_dir,new_folder)
new_dir1
# Out:
# 'C:\\Users\\pavan kalyan\\Desktop\\Naresh I technologies\\Data Science\\New folder\\bank_graphs_matplotlib'

# %%
os.makedirs(new_dir)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 os.makedirs(new_dir)
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\pavan kalyan\\Desktop\\Naresh I technologies\\Data Science\\New folder\\bank_graphs_matplotlib'

# %%
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
cdf=bank_df['bank_df'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bank_df'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[118], line 1
# ...

# %%
#bank_df=pd.read_csv(path)

# %%
for i in cat_columns[1:]:
    cdf=bank_df[i].value_counts()
    keys=cdf.keys()
    values=cdf.values
    cols=['Labels','Count']
    df=pd.DataFrame(zip(keys,values),columns=cols)
    path=r"new_dir"
    bank_df.to_csv(f"{new_dir1}\\{i}.csv",index=False)

# %%
try:
    root_dir=os.getcwd()
    new_folder='bank_count'
    dir=os.path.join(root_dir,new_folder)
    os.makedirs(new_dir1)
   # cwd is   current working directory
except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\pavan kalyan\\Desktop\\Naresh I technologies\\Data Science\\New folder\\bank_graphs_matplotlib'

# %%
dfs=os.listdir(r"C:\Users\pavan kalyan\Desktop\Naresh I technologies\Data Science\New folder\bank_count")
dfs
# Out:
# ['contact.csv',
#  'default.csv',
#  'education.csv',
#  'housing.csv',
#  'loan.csv',
#  'marital.csv',
#  'month.csv',
#  'poutcome.csv',
#  'y.csv']

# %%
root_die=os.getcwd()
new_folder='bank_count'
dir=os.path.join(root_dir,new_folder)
dir
# Out:
# 'C:\\Users\\pavan kalyan\\Desktop\\Naresh I technologies\\Data Science\\New folder\\bank_count'

# %%
dfs=os.listdir(dir)
dfs
# Out:
# ['contact.csv',
#  'default.csv',
#  'education.csv',
#  'housing.csv',
#  'loan.csv',
#  'marital.csv',
#  'month.csv',
#  'poutcome.csv',
#  'y.csv']

# %%
import pandas as pd

# %%
# for i in dfs:
#     cdf=bank_df[i].value_counts()
#     keys=cdf.keys()
#     values=cdf.values
#     cols=['Labels','Count']
#     df=pd.DataFrame(zip(keys,values),
#                    columns=cols)
#     path=r"C:\Users\pavan kalyan\Desktop\Naresh I technologies\Data Science\New folder\bank_graphs_matplotlib'"
#     bank_df.to_csv(f"{path}\\{i}.csv",index=False)

# %%
import matplotlib.pyplot as plt

# %%
for i in cat_columns[1:]:
    cdf=bank_df[i].value_counts()
    keys=cdf.keys()
    values=cdf.values
    cols=['Labels','Count']
    df=pd.DataFrame(zip(keys,values),columns=cols)
    path=r"C:\Users\pavan kalyan\Desktop\Naresh I technologies\Data Science\New folder\bank_count"
    bank_df.to_csv(f"{path}\\{i}.csv",index=False)

# %%
try:
    root_dir=os.getcwd()
    new_folder='bank_graphs_matplotlib'
    dir=os.path.join(root_dir,new_folder)
    os.makedirs(new_dir1)
   # cwd is   current working directory
except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\pavan kalyan\\Desktop\\Naresh I technologies\\Data Science\\New folder\\bank_graphs_matplotlib'

# %%
dfs=os.listdir(r"C:\Users\pavan kalyan\Desktop\Naresh I technologies\Data Science\New folder\bank_count")
dfs
# Out:
# ['contact.csv',
#  'default.csv',
#  'education.csv',
#  'housing.csv',
#  'loan.csv',
#  'marital.csv',
#  'month.csv',
#  'poutcome.csv',
#  'y.csv']

# %%
root_dir=os.getcwd()
new_folder='bank_count'
dir1=os.path.join(root_dir,new_folder)
dir1
# Out:
# 'C:\\Users\\pavan kalyan\\Desktop\\Naresh I technologies\\Data Science\\New folder\\bank_count'

# %%
#pd.read_csv(bank_df.csv)

# %%
dfs=os.listdir(dir1)
dfs
# Out:
# ['contact.csv',
#  'default.csv',
#  'education.csv',
#  'housing.csv',
#  'loan.csv',
#  'marital.csv',
#  'month.csv',
#  'poutcome.csv',
#  'y.csv']

# %%
for i in dfs:
    #read=pd.read_csv(f"{new_dir}\\{i}")
    dfs= pd.read_csv(f"{dir1}\\{i}")
    plt.bar('Labels',
         'Count'
         ,data=df)
    plt.title(f"{i} bank Bar Chart")
    plt.xlabel("Label")
    plt.ylabel("Count")
    plt.savefig(f"{new_dir1}\\{i}_matplotlib.jpg")
    plt.show()

# %%
import seaborn as sns

# %%
for i in cat_columns[1:]:
    plt.figure(figsize=(8,5))
    order_i=bank_df[i].value_counts().keys()
    sns.countplot(data=bank_df,x=i,order=order_i)
    plt.xlabel(i)
    plt.ylabel("Count")
    plt.savefig(f"{new_dir1}'\'{i}_seaborn.jpg")
    plt.title('Bar chart')
    plt.show()

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank_df.loc[:,'marital']
# Out:
# 0       married
# 1       married
# 2        single
# 3       married
# 4       married
#          ...
# 4516    married
# 4517    married
# 4518    married
# 4519    married
# 4520     single
# Name: marital, Length: 4521, dtype: object

# %%
bank_df[['marital']]
# Out:
#       marital
# 0     married
# 1     married
# 2      single
# 3     married
# 4     married
# ...       ...
# 4516  married
# 4517  married
# 4518  married
# 4519  married
# 4520   single
#
# [4521 rows x 1 columns]

# %%
bank_df.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
marital_data=bank_df['marital']

# %%
plt.hist(bank_df['marital'],bins=10)
plt.show()

# %%
balance_data=bank_df['balance']
plt.hist(bank_df['balance'],bins=9)
plt.show()

# %%
age_data=bank_df['age']
plt.hist(bank_df['age'],bins=20)
plt.show()

# %%
day_data=bank_df['day']
plt.hist(bank_df['day'],bins=30)
plt.show()

# %%
duration_data=bank_df['duration']
plt.hist(bank_df['duration'],bins=20)
plt.show()

# %%
campaign_data=bank_df['campaign']
plt.hist(bank_df['campaign'],bins=10)
plt.show()

# %%
pdays_data=bank_df['pdays']
plt.hist(bank_df['pdays'],bins=9)
plt.show()

# %%
previous_data=bank_df['previous']
plt.hist(bank_df['previous'],bins=18)
plt.show()

# %%
cat_columns=bank_df.select_dtypes(include='object').columns
num_columns=bank_df.select_dtypes(exclude='object').columns
num_columns
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
for i in num_columns[1:]:
    plt.figure(figsize=(8,5))
    order_i=bank_df[i].value_counts().keys()
    sns.countplot(data=bank_df,x=i,order=order_i)
    plt.xlabel(i)
    plt.ylabel("Count")
    plt.savefig(f"{new_dir1}'\'{i}_seaborn.jpg")
    plt.title('Bar chart')
    plt.show()

# %%
for i in num_columns[1:]:
    plt.figure(figsize=(8,5))
    order_i=bank_df[i].value_counts().keys()
    sns.histplot(data=bank_df,x=i,bins=20,order=order_i)
    plt.xlabel(i)
    plt.ylabel("Count")
    plt.savefig(f"{new_dir1}'\'{i}_seaborn.jpg")
    plt.title('Bar chart')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[164], line 4
#       2 plt.figure(figsize=(8,5))
#       3 order_i=bank_df[i].value_counts().keys()
# ----> 4 sns.histplot(data=bank_df,x=i,bins=20,order=order_i)
#       5 plt.xlabel(i)
#       6 plt.ylabel("Count")
#
# File ~\anaconda3\Lib\site-packages\seaborn\distributions.py:1412, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1410     else:
#    1411         method = ax.plot
# -> 1412     color = _default_color(method, hue, color, kwargs)
#    1414 if not p.has_xy_data:
#    1415     return ax
#
# ...

# %%
bank_df
